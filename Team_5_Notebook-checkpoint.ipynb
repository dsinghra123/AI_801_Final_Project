# %% [markdown]
# ### Load all necessary libraries for the analysis

# %%
import cv2
import glob
import h5py
import keras_tuner as kt
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import tensorflow as tf

import keras

from keras import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam, Adamax

from collections import Counter
from mpl_toolkits.axes_grid1 import ImageGrid
from sklearn.metrics import confusion_matrix
from difPy import dif

# %% [markdown]
# ### Identify primary directories for the analysis

# %%
# Parent directory path.  This directory is the parent directory for the entire project and likely the working directory 
os.chdir('D:/School_Files/AI_801/Project/final_project_git')

# Directory to master image file
image_dir = './data/' 

# Directory to augmented image file
aug_path = './birds_augmented'

# Directory to weights path
best_weights_path_cnn = "./best_weights_6conv_birds.hdf5"

best_weights_path_tuned = "./best_weights_6conv_birds_tuned.hdf5"

best_weights_path_EN = "./best_weights_6conv_birds_RGB.hdf5"

# Directory to weights path after tuning
#tuned_best_weights_path = "./tuned_best_weights_6conv_simpsons.hdf5"
efficient_dir = './efficient/' 

# Directory to save model for app
best_model_save = "./model_birds.hdf5"

# Directory to app image
app_image = './app_image/'

# %% [markdown]
# ### Identify all fixed variables that will be used in the functions below

# %%
# Create dictionary that provides key and name of each folder in the master image directory
map_birds = dict(list(enumerate([os.path.basename(x) for x in glob.glob(image_dir + '/train/*')])))

# Identify fixed variables
num_classes = 375
pic_size = 224 #The size that each image will be modified to
batch_size = 32 #The batch size the images will be fed through the model
epochs = 30 #The number of epochs that will be run
num_classes = len(map_birds) #The number of classes for the analysis (number of characters)
train_steps=int(np.ceil(num_classes/batch_size))
train_images = 120

# %% [markdown]
# ### Initial exploratiory analytics for the dataset

# %%
# Get the min and max number of images from the dataset
species_size = []
for k, char in map_birds.items():
    species_size.append(len(glob.glob(image_dir + '/train/%s/*' % char)))
print('Minimum number of images is ' + str(min(species_size)))
print('Maximimum number of images is ' + str(max(species_size)))
# Out:
# Minimum number of images is 120
# Maximimum number of images is 249

# %% [markdown]
# ### Test to determine of all images are size (224, 224, 3) as the dataset claims

# %%
image_size = []
for k, char in map_birds.items():
    pictures_size = [k for k in glob.glob(image_dir + '/train/%s/*' % char)]

    for pic in pictures_size:
        a = cv2.imread(pic)
        image_size.append(a.shape)   
print('Total number of images not equal to (224, 224, 3) = ' + str(sum(x != (224, 224, 3) for x in image_size)))
# Out:
# Total number of images not equal to (224, 224, 3) = 0

# %% [markdown]
# ### Identify if duplicate images are present in the dataset

# %%
dup_images = []

for k, char in map_birds.items():
    search = dif(image_dir + '/train/%s/' % char)
    dup_images.append(search.result) 
cat_count = 0
cat_sum = 0

for x in dup_images:
    y = len(x)
    if y > 0 :
        cat_count = cat_count + 1
        cat_sum += y
print('Number of species with duplicate images = ' + str(cat_count))
print('Total duplicate images = ' + str(cat_sum))
# Out:
# Found 1 image with one or more duplicate/similar images in 2.5369 seconds.
# Found 0 images with one or more duplicate/similar images in 2.9692 seconds.
# Found 0 images with one or more duplicate/similar images in 2.91 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7771 seconds.
# Found 0 images with one or more duplicate/similar images in 1.969 seconds.
# Found 0 images with one or more duplicate/similar images in 1.741 seconds.
# Found 0 images with one or more duplicate/similar images in 1.5613 seconds.
# Found 1 image with one or more duplicate/similar images in 1.647 seconds.
# Found 0 images with one or more duplicate/similar images in 2.4 seconds.
# Found 0 images with one or more duplicate/similar images in 2.5141 seconds.
# Found 0 images with one or more duplicate/similar images in 2.527 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4721 seconds.
# Found 0 images with one or more duplicate/similar images in 2.94 seconds.
# Found 0 images with one or more duplicate/similar images in 2.6753 seconds.
# Found 0 images with one or more duplicate/similar images in 2.309 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6571 seconds.
# Found 0 images with one or more duplicate/similar images in 1.608 seconds.
# Found 0 images with one or more duplicate/similar images in 3.0331 seconds.
# Found 0 images with one or more duplicate/similar images in 1.844 seconds.
# Found 0 images with one or more duplicate/similar images in 1.601 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6812 seconds.
# Found 0 images with one or more duplicate/similar images in 1.925 seconds.
# Found 0 images with one or more duplicate/similar images in 2.016 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0081 seconds.
# Found 0 images with one or more duplicate/similar images in 2.091 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7891 seconds.
# Found 0 images with one or more duplicate/similar images in 2.099 seconds.
# Found 0 images with one or more duplicate/similar images in 1.833 seconds.
# Found 0 images with one or more duplicate/similar images in 2.251 seconds.
# Found 0 images with one or more duplicate/similar images in 2.15 seconds.
# Found 1 image with one or more duplicate/similar images in 2.2562 seconds.
# Found 0 images with one or more duplicate/similar images in 2.095 seconds.
# Found 0 images with one or more duplicate/similar images in 2.3042 seconds.
# Found 0 images with one or more duplicate/similar images in 1.738 seconds.
# Found 0 images with one or more duplicate/similar images in 1.773 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4531 seconds.
# Found 0 images with one or more duplicate/similar images in 2.088 seconds.
# Found 0 images with one or more duplicate/similar images in 2.378 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0172 seconds.
# Found 0 images with one or more duplicate/similar images in 1.634 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7552 seconds.
# Found 0 images with one or more duplicate/similar images in 2.563 seconds.
# Found 0 images with one or more duplicate/similar images in 1.437 seconds.
# Found 0 images with one or more duplicate/similar images in 3.5158 seconds.
# Found 0 images with one or more duplicate/similar images in 2.6084 seconds.
# Found 0 images with one or more duplicate/similar images in 1.602 seconds.
# Found 0 images with one or more duplicate/similar images in 1.404 seconds.
# Found 0 images with one or more duplicate/similar images in 1.413 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6681 seconds.
# Found 0 images with one or more duplicate/similar images in 1.845 seconds.
# Found 0 images with one or more duplicate/similar images in 1.72 seconds.
# Found 0 images with one or more duplicate/similar images in 1.9861 seconds.
# Found 0 images with one or more duplicate/similar images in 2.455 seconds.
# Found 0 images with one or more duplicate/similar images in 1.8972 seconds.
# Found 0 images with one or more duplicate/similar images in 1.965 seconds.
# Found 0 images with one or more duplicate/similar images in 1.476 seconds.
# Found 1 image with one or more duplicate/similar images in 1.5562 seconds.
# Found 0 images with one or more duplicate/similar images in 1.896 seconds.
# Found 0 images with one or more duplicate/similar images in 2.2849 seconds.
# Found 1 image with one or more duplicate/similar images in 1.72 seconds.
# Found 0 images with one or more duplicate/similar images in 1.624 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4062 seconds.
# Found 0 images with one or more duplicate/similar images in 2.119 seconds.
# Found 0 images with one or more duplicate/similar images in 2.108 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4261 seconds.
# Found 0 images with one or more duplicate/similar images in 1.751 seconds.
# Found 0 images with one or more duplicate/similar images in 1.533 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7391 seconds.
# Found 0 images with one or more duplicate/similar images in 1.79 seconds.
# Found 0 images with one or more duplicate/similar images in 2.8571 seconds.
# Found 0 images with one or more duplicate/similar images in 1.754 seconds.
# Found 0 images with one or more duplicate/similar images in 2.038 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0611 seconds.
# Found 0 images with one or more duplicate/similar images in 3.283 seconds.
# Found 1 image with one or more duplicate/similar images in 2.7522 seconds.
# Found 0 images with one or more duplicate/similar images in 2.223 seconds.
# Found 0 images with one or more duplicate/similar images in 2.5091 seconds.
# Found 0 images with one or more duplicate/similar images in 1.796 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4432 seconds.
# Found 0 images with one or more duplicate/similar images in 1.546 seconds.
# Found 0 images with one or more duplicate/similar images in 1.577 seconds.
# Found 0 images with one or more duplicate/similar images in 2.9362 seconds.
# Found 0 images with one or more duplicate/similar images in 1.586 seconds.
# Found 2 images with one or more duplicate/similar images in 2.5936 seconds.
# Found 0 images with one or more duplicate/similar images in 1.374 seconds.
# Found 0 images with one or more duplicate/similar images in 2.412 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4101 seconds.
# Found 0 images with one or more duplicate/similar images in 2.197 seconds.
# Found 0 images with one or more duplicate/similar images in 1.372 seconds.
# Found 0 images with one or more duplicate/similar images in 1.3943 seconds.
# Found 0 images with one or more duplicate/similar images in 2.434 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0361 seconds.
# Found 0 images with one or more duplicate/similar images in 1.716 seconds.
# Found 0 images with one or more duplicate/similar images in 2.043 seconds.
# Found 0 images with one or more duplicate/similar images in 2.3096 seconds.
# Found 0 images with one or more duplicate/similar images in 1.833 seconds.
# Found 0 images with one or more duplicate/similar images in 1.721 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4272 seconds.
# Found 0 images with one or more duplicate/similar images in 4.2836 seconds.
# Found 0 images with one or more duplicate/similar images in 2.177 seconds.
# Found 0 images with one or more duplicate/similar images in 3.0531 seconds.
# Found 0 images with one or more duplicate/similar images in 2.485 seconds.
# Found 0 images with one or more duplicate/similar images in 1.604 seconds.
# Found 0 images with one or more duplicate/similar images in 1.789 seconds.
# Found 0 images with one or more duplicate/similar images in 1.648 seconds.
# Found 0 images with one or more duplicate/similar images in 1.466 seconds.
# Found 0 images with one or more duplicate/similar images in 2.2592 seconds.
# Found 0 images with one or more duplicate/similar images in 1.511 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0092 seconds.
# Found 0 images with one or more duplicate/similar images in 3.266 seconds.
# Found 0 images with one or more duplicate/similar images in 1.5161 seconds.
# Found 0 images with one or more duplicate/similar images in 2.143 seconds.
# Found 0 images with one or more duplicate/similar images in 1.432 seconds.
# Found 0 images with one or more duplicate/similar images in 3.0451 seconds.
# Found 0 images with one or more duplicate/similar images in 1.509 seconds.
# Found 0 images with one or more duplicate/similar images in 2.6781 seconds.
# Found 0 images with one or more duplicate/similar images in 3.01 seconds.
# Found 0 images with one or more duplicate/similar images in 1.9288 seconds.
# Found 0 images with one or more duplicate/similar images in 3.055 seconds.
# Found 0 images with one or more duplicate/similar images in 1.5781 seconds.
# Found 0 images with one or more duplicate/similar images in 1.704 seconds.
# Found 0 images with one or more duplicate/similar images in 1.415 seconds.
# Found 0 images with one or more duplicate/similar images in 2.5591 seconds.
# Found 0 images with one or more duplicate/similar images in 1.93 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0142 seconds.
# Found 0 images with one or more duplicate/similar images in 2.008 seconds.
# Found 0 images with one or more duplicate/similar images in 1.773 seconds.
# Found 0 images with one or more duplicate/similar images in 1.8807 seconds.
# Found 0 images with one or more duplicate/similar images in 1.404 seconds.
# Found 0 images with one or more duplicate/similar images in 2.051 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0522 seconds.
# Found 0 images with one or more duplicate/similar images in 2.016 seconds.
# Found 0 images with one or more duplicate/similar images in 2.1649 seconds.
# Found 0 images with one or more duplicate/similar images in 2.258 seconds.
# Found 0 images with one or more duplicate/similar images in 2.1791 seconds.
# Found 0 images with one or more duplicate/similar images in 2.388 seconds.
# Found 0 images with one or more duplicate/similar images in 2.382 seconds.
# Found 0 images with one or more duplicate/similar images in 3.8472 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4502 seconds.
# Found 0 images with one or more duplicate/similar images in 1.454 seconds.
# Found 0 images with one or more duplicate/similar images in 1.469 seconds.
# Found 0 images with one or more duplicate/similar images in 1.9166 seconds.
# Found 0 images with one or more duplicate/similar images in 1.877 seconds.
# Found 0 images with one or more duplicate/similar images in 5.3241 seconds.
# Found 0 images with one or more duplicate/similar images in 4.1732 seconds.
# Found 0 images with one or more duplicate/similar images in 1.983 seconds.
# Found 0 images with one or more duplicate/similar images in 2.3577 seconds.
# Found 0 images with one or more duplicate/similar images in 3.458 seconds.
# Found 0 images with one or more duplicate/similar images in 2.7521 seconds.
# Found 0 images with one or more duplicate/similar images in 1.695 seconds.
# Found 0 images with one or more duplicate/similar images in 1.5486 seconds.
# Found 0 images with one or more duplicate/similar images in 1.69 seconds.
# Found 0 images with one or more duplicate/similar images in 2.309 seconds.
# Found 0 images with one or more duplicate/similar images in 3.6111 seconds.
# Found 0 images with one or more duplicate/similar images in 1.443 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6231 seconds.
# Found 0 images with one or more duplicate/similar images in 2.079 seconds.
# Found 0 images with one or more duplicate/similar images in 2.237 seconds.
# Found 0 images with one or more duplicate/similar images in 1.721 seconds.
# Found 0 images with one or more duplicate/similar images in 1.497 seconds.
# Found 0 images with one or more duplicate/similar images in 1.5803 seconds.
# Found 0 images with one or more duplicate/similar images in 1.894 seconds.
# Found 0 images with one or more duplicate/similar images in 2.49 seconds.
# Found 0 images with one or more duplicate/similar images in 2.1096 seconds.
# Found 0 images with one or more duplicate/similar images in 2.563 seconds.
# Found 0 images with one or more duplicate/similar images in 2.3196 seconds.
# Found 0 images with one or more duplicate/similar images in 3.045 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4731 seconds.
# Found 0 images with one or more duplicate/similar images in 1.448 seconds.
# Found 0 images with one or more duplicate/similar images in 2.162 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0306 seconds.
# Found 0 images with one or more duplicate/similar images in 2.154 seconds.
# Found 0 images with one or more duplicate/similar images in 1.9334 seconds.
# Found 0 images with one or more duplicate/similar images in 3.146 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7036 seconds.
# Found 0 images with one or more duplicate/similar images in 2.504 seconds.
# Found 0 images with one or more duplicate/similar images in 3.0606 seconds.
# Found 0 images with one or more duplicate/similar images in 1.796 seconds.
# Found 2 images with one or more duplicate/similar images in 1.516 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4886 seconds.
# Found 0 images with one or more duplicate/similar images in 1.448 seconds.
# Found 0 images with one or more duplicate/similar images in 1.758 seconds.
# Found 0 images with one or more duplicate/similar images in 2.4126 seconds.
# Found 0 images with one or more duplicate/similar images in 2.156 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4396 seconds.
# Found 0 images with one or more duplicate/similar images in 2.058 seconds.
# Found 0 images with one or more duplicate/similar images in 2.82 seconds.
# Found 0 images with one or more duplicate/similar images in 1.8773 seconds.
# Found 0 images with one or more duplicate/similar images in 3.3576 seconds.
# Found 0 images with one or more duplicate/similar images in 1.939 seconds.
# Found 0 images with one or more duplicate/similar images in 2.472 seconds.
# Found 0 images with one or more duplicate/similar images in 3.2953 seconds.
# Found 0 images with one or more duplicate/similar images in 1.499 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6205 seconds.
# Found 0 images with one or more duplicate/similar images in 2.735 seconds.
# Found 0 images with one or more duplicate/similar images in 1.9986 seconds.
# Found 0 images with one or more duplicate/similar images in 1.591 seconds.
# Found 0 images with one or more duplicate/similar images in 2.393 seconds.
# Found 0 images with one or more duplicate/similar images in 3.1461 seconds.
# Found 0 images with one or more duplicate/similar images in 1.521 seconds.
# Found 0 images with one or more duplicate/similar images in 1.5689 seconds.
# Found 0 images with one or more duplicate/similar images in 2.431 seconds.
# Found 0 images with one or more duplicate/similar images in 2.5387 seconds.
# Found 0 images with one or more duplicate/similar images in 1.869 seconds.
# Found 0 images with one or more duplicate/similar images in 1.656 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4981 seconds.
# Found 0 images with one or more duplicate/similar images in 1.445 seconds.
# Found 0 images with one or more duplicate/similar images in 2.9673 seconds.
# Found 0 images with one or more duplicate/similar images in 1.617 seconds.
# Found 0 images with one or more duplicate/similar images in 6.1662 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6 seconds.
# Found 0 images with one or more duplicate/similar images in 2.7496 seconds.
# Found 0 images with one or more duplicate/similar images in 2.094 seconds.
# Found 0 images with one or more duplicate/similar images in 2.2021 seconds.
# Found 0 images with one or more duplicate/similar images in 1.697 seconds.
# Found 0 images with one or more duplicate/similar images in 3.3831 seconds.
# Found 0 images with one or more duplicate/similar images in 3.4456 seconds.
# Found 0 images with one or more duplicate/similar images in 2.168 seconds.
# Found 0 images with one or more duplicate/similar images in 2.171 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0735 seconds.
# Found 0 images with one or more duplicate/similar images in 1.473 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0811 seconds.
# Found 0 images with one or more duplicate/similar images in 1.702 seconds.
# Found 0 images with one or more duplicate/similar images in 3.0691 seconds.
# Found 0 images with one or more duplicate/similar images in 1.863 seconds.
# Found 0 images with one or more duplicate/similar images in 1.905 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0748 seconds.
# Found 0 images with one or more duplicate/similar images in 1.484 seconds.
# Found 0 images with one or more duplicate/similar images in 1.622 seconds.
# Found 0 images with one or more duplicate/similar images in 1.9081 seconds.
# Found 0 images with one or more duplicate/similar images in 1.442 seconds.
# Found 0 images with one or more duplicate/similar images in 2.025 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7217 seconds.
# Found 0 images with one or more duplicate/similar images in 2.633 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0206 seconds.
# Found 0 images with one or more duplicate/similar images in 1.459 seconds.
# Found 0 images with one or more duplicate/similar images in 1.845 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7581 seconds.
# Found 0 images with one or more duplicate/similar images in 1.929 seconds.
# Found 0 images with one or more duplicate/similar images in 3.9116 seconds.
# Found 0 images with one or more duplicate/similar images in 1.711 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6707 seconds.
# Found 0 images with one or more duplicate/similar images in 2.078 seconds.
# Found 0 images with one or more duplicate/similar images in 1.565 seconds.
# Found 0 images with one or more duplicate/similar images in 1.9286 seconds.
# Found 0 images with one or more duplicate/similar images in 1.62 seconds.
# Found 0 images with one or more duplicate/similar images in 2.464 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6431 seconds.
# Found 0 images with one or more duplicate/similar images in 1.925 seconds.
# Found 0 images with one or more duplicate/similar images in 1.8252 seconds.
# Found 0 images with one or more duplicate/similar images in 2.032 seconds.
# Found 0 images with one or more duplicate/similar images in 1.415 seconds.
# Found 0 images with one or more duplicate/similar images in 2.3772 seconds.
# Found 0 images with one or more duplicate/similar images in 1.917 seconds.
# Found 0 images with one or more duplicate/similar images in 3.5687 seconds.
# Found 0 images with one or more duplicate/similar images in 1.837 seconds.
# Found 0 images with one or more duplicate/similar images in 1.656 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4629 seconds.
# Found 0 images with one or more duplicate/similar images in 1.462 seconds.
# Found 0 images with one or more duplicate/similar images in 1.704 seconds.
# Found 0 images with one or more duplicate/similar images in 1.5802 seconds.
# Found 0 images with one or more duplicate/similar images in 1.608 seconds.
# Found 0 images with one or more duplicate/similar images in 1.489 seconds.
# Found 0 images with one or more duplicate/similar images in 5.3151 seconds.
# Found 0 images with one or more duplicate/similar images in 4.1361 seconds.
# Found 0 images with one or more duplicate/similar images in 2.5936 seconds.
# Found 0 images with one or more duplicate/similar images in 1.446 seconds.
# Found 0 images with one or more duplicate/similar images in 3.0176 seconds.
# Found 0 images with one or more duplicate/similar images in 1.653 seconds.
# Found 0 images with one or more duplicate/similar images in 1.514 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7453 seconds.
# Found 0 images with one or more duplicate/similar images in 2.404 seconds.
# Found 0 images with one or more duplicate/similar images in 1.453 seconds.
# Found 0 images with one or more duplicate/similar images in 1.5686 seconds.
# Found 0 images with one or more duplicate/similar images in 2.414 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6236 seconds.
# Found 0 images with one or more duplicate/similar images in 1.981 seconds.
# Found 0 images with one or more duplicate/similar images in 1.628 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6982 seconds.
# Found 0 images with one or more duplicate/similar images in 1.715 seconds.
# Found 0 images with one or more duplicate/similar images in 1.488 seconds.
# Found 0 images with one or more duplicate/similar images in 2.3512 seconds.
# Found 0 images with one or more duplicate/similar images in 2.924 seconds.
# Found 0 images with one or more duplicate/similar images in 2.2356 seconds.
# Found 0 images with one or more duplicate/similar images in 2.02 seconds.
# Found 0 images with one or more duplicate/similar images in 3.799 seconds.
# Found 0 images with one or more duplicate/similar images in 3.8321 seconds.
# Found 0 images with one or more duplicate/similar images in 2.271 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0032 seconds.
# Found 0 images with one or more duplicate/similar images in 1.63 seconds.
# Found 0 images with one or more duplicate/similar images in 2.769 seconds.
# Found 0 images with one or more duplicate/similar images in 2.7022 seconds.
# Found 0 images with one or more duplicate/similar images in 1.513 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7721 seconds.
# Found 0 images with one or more duplicate/similar images in 1.73 seconds.
# Found 0 images with one or more duplicate/similar images in 2.558 seconds.
# Found 0 images with one or more duplicate/similar images in 4.0891 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7074 seconds.
# Found 0 images with one or more duplicate/similar images in 1.607 seconds.
# Found 0 images with one or more duplicate/similar images in 1.55 seconds.
# Found 0 images with one or more duplicate/similar images in 1.5292 seconds.
# Found 0 images with one or more duplicate/similar images in 2.29 seconds.
# Found 0 images with one or more duplicate/similar images in 1.504 seconds.
# Found 0 images with one or more duplicate/similar images in 2.1551 seconds.
# Found 0 images with one or more duplicate/similar images in 1.761 seconds.
# Found 0 images with one or more duplicate/similar images in 1.938 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6142 seconds.
# Found 0 images with one or more duplicate/similar images in 2.011 seconds.
# Found 0 images with one or more duplicate/similar images in 1.9306 seconds.
# Found 0 images with one or more duplicate/similar images in 2.557 seconds.
# Found 0 images with one or more duplicate/similar images in 2.3221 seconds.
# Found 0 images with one or more duplicate/similar images in 3.367 seconds.
# Found 0 images with one or more duplicate/similar images in 1.574 seconds.
# Found 0 images with one or more duplicate/similar images in 2.182 seconds.
# Found 0 images with one or more duplicate/similar images in 2.323 seconds.
# Found 0 images with one or more duplicate/similar images in 2.8307 seconds.
# Found 0 images with one or more duplicate/similar images in 2.378 seconds.
# Found 0 images with one or more duplicate/similar images in 1.9425 seconds.
# Found 0 images with one or more duplicate/similar images in 1.451 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7351 seconds.
# Found 0 images with one or more duplicate/similar images in 3.066 seconds.
# Found 0 images with one or more duplicate/similar images in 2.6351 seconds.
# Found 0 images with one or more duplicate/similar images in 1.478 seconds.
# Found 0 images with one or more duplicate/similar images in 1.726 seconds.
# Found 0 images with one or more duplicate/similar images in 2.5462 seconds.
# Found 0 images with one or more duplicate/similar images in 3.9275 seconds.
# Found 0 images with one or more duplicate/similar images in 1.447 seconds.
# Found 0 images with one or more duplicate/similar images in 1.45 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0302 seconds.
# Found 0 images with one or more duplicate/similar images in 3.683 seconds.
# Found 0 images with one or more duplicate/similar images in 2.2231 seconds.
# Found 0 images with one or more duplicate/similar images in 2.587 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4601 seconds.
# Found 0 images with one or more duplicate/similar images in 1.779 seconds.
# Found 0 images with one or more duplicate/similar images in 2.673 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0146 seconds.
# Found 0 images with one or more duplicate/similar images in 2.032 seconds.
# Found 0 images with one or more duplicate/similar images in 1.4161 seconds.
# Found 0 images with one or more duplicate/similar images in 2.004 seconds.
# Found 0 images with one or more duplicate/similar images in 4.5403 seconds.
# Found 0 images with one or more duplicate/similar images in 1.947 seconds.
# Found 0 images with one or more duplicate/similar images in 1.7911 seconds.
# Found 0 images with one or more duplicate/similar images in 1.424 seconds.
# Found 1 image with one or more duplicate/similar images in 1.773 seconds.
# Found 0 images with one or more duplicate/similar images in 2.4891 seconds.
# Found 0 images with one or more duplicate/similar images in 2.036 seconds.
# Found 0 images with one or more duplicate/similar images in 1.8072 seconds.
# Found 0 images with one or more duplicate/similar images in 2.625 seconds.
# Found 0 images with one or more duplicate/similar images in 3.1106 seconds.
# Found 0 images with one or more duplicate/similar images in 2.056 seconds.
# Found 0 images with one or more duplicate/similar images in 1.777 seconds.
# Found 0 images with one or more duplicate/similar images in 2.1181 seconds.
# Found 0 images with one or more duplicate/similar images in 2.32 seconds.
# Found 0 images with one or more duplicate/similar images in 1.9688 seconds.
# Found 0 images with one or more duplicate/similar images in 3.52 seconds.
# Found 0 images with one or more duplicate/similar images in 1.5552 seconds.
# Found 0 images with one or more duplicate/similar images in 2.307 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0441 seconds.
# Found 0 images with one or more duplicate/similar images in 3.799 seconds.
# Found 0 images with one or more duplicate/similar images in 2.6973 seconds.
# Found 0 images with one or more duplicate/similar images in 2.875 seconds.
# Found 0 images with one or more duplicate/similar images in 1.8642 seconds.
# Found 0 images with one or more duplicate/similar images in 1.947 seconds.
# Found 0 images with one or more duplicate/similar images in 1.8521 seconds.
# Found 0 images with one or more duplicate/similar images in 2.306 seconds.
# Found 0 images with one or more duplicate/similar images in 2.2638 seconds.
# Found 0 images with one or more duplicate/similar images in 1.432 seconds.
# Found 0 images with one or more duplicate/similar images in 2.843 seconds.
# Found 0 images with one or more duplicate/similar images in 2.0741 seconds.
# Found 0 images with one or more duplicate/similar images in 1.997 seconds.
# Found 0 images with one or more duplicate/similar images in 1.515 seconds.
# Found 0 images with one or more duplicate/similar images in 4.3341 seconds.
# Found 0 images with one or more duplicate/similar images in 1.6251 seconds.
# Found 0 images with one or more duplicate/similar images in 2.322 seconds.
# Found 0 images with one or more duplicate/similar images in 2.3512 seconds.
# Number of species with duplicate images = 9
# Total duplicate images = 11

# %% [markdown]
# ### Dedup images

# %%
# First will create a copy of the images called dedup_train
shutil.copytree(image_dir + '/train/', image_dir + '/dedup_train/')

# Next we will loop through all folders in our new directory and delete the duplicate images
for k, char in map_birds.items():
    result = dif(image_dir + '/dedup_train/%s/' % char, show_output=True, delete=True)

# %% [markdown]
# ### Create a function to further augment the images, first create the necessary folders

# %%
def image_augmentation(train_images = train_images):
    # Check if augmented directory exists
    folder_check = os.path.isdir(aug_path)
               
    if not folder_check:
        os.makedirs(aug_path)
        print("created folder : ", aug_path)
    else:
        print(aug_path, "already exists.")
        
    for k, char in map_birds.items():
        
        file = aug_path + '/train/' + '/%s/' % char
        # Creating partitions of the data after shuffling
        
        sub_folder_check = os.path.isdir(file)
        
        if not sub_folder_check:
            os.makedirs(file)
            print("Created Folder: ", file)
        else:
            print(file, "already exists.")

# %% [markdown]
# ### Create another function that selects only 120 images from each species of bird to ensure our data set is balanced

# %%
def image_selection():
    
    for k, char in map_birds.items():   
        
        file = aug_path + '/train/' + '/%s/' % char
        src = image_dir +'/dedup_train/' + char  # Folder to copy images from
        dest = file       
        src_files = os.listdir(src)
        
        for file_name in src_files[:train_images]:
            full_file_name = os.path.join(src, file_name)
            if os.path.isfile(full_file_name):
                shutil.copy(full_file_name, dest)        
            else:
                print(dest, "already exists.")          
            
image_augmentation()            
image_selection()
# Out:
# ./birds_augmented already exists.
# ./birds_augmented/train//ABBOTTS BABBLER/ already exists.
# ./birds_augmented/train//ABBOTTS BOOBY/ already exists.
# ./birds_augmented/train//ABYSSINIAN GROUND HORNBILL/ already exists.
# ./birds_augmented/train//AFRICAN CROWNED CRANE/ already exists.
# ./birds_augmented/train//AFRICAN EMERALD CUCKOO/ already exists.
# ./birds_augmented/train//AFRICAN FIREFINCH/ already exists.
# ./birds_augmented/train//AFRICAN OYSTER CATCHER/ already exists.
# ./birds_augmented/train//ALBATROSS/ already exists.
# ./birds_augmented/train//ALBERTS TOWHEE/ already exists.
# ./birds_augmented/train//ALEXANDRINE PARAKEET/ already exists.
# ./birds_augmented/train//ALPINE CHOUGH/ already exists.
# ./birds_augmented/train//ALTAMIRA YELLOWTHROAT/ already exists.
# ./birds_augmented/train//AMERICAN AVOCET/ already exists.
# ./birds_augmented/train//AMERICAN BITTERN/ already exists.
# ./birds_augmented/train//AMERICAN COOT/ already exists.
# ./birds_augmented/train//AMERICAN GOLDFINCH/ already exists.
# ./birds_augmented/train//AMERICAN KESTREL/ already exists.
# ./birds_augmented/train//AMERICAN PIPIT/ already exists.
# ./birds_augmented/train//AMERICAN REDSTART/ already exists.
# ./birds_augmented/train//AMETHYST WOODSTAR/ already exists.
# ./birds_augmented/train//ANDEAN GOOSE/ already exists.
# ./birds_augmented/train//ANDEAN LAPWING/ already exists.
# ./birds_augmented/train//ANDEAN SISKIN/ already exists.
# ./birds_augmented/train//ANHINGA/ already exists.
# ./birds_augmented/train//ANIANIAU/ already exists.
# ./birds_augmented/train//ANNAS HUMMINGBIRD/ already exists.
# ./birds_augmented/train//ANTBIRD/ already exists.
# ./birds_augmented/train//ANTILLEAN EUPHONIA/ already exists.
# ./birds_augmented/train//APAPANE/ already exists.
# ./birds_augmented/train//APOSTLEBIRD/ already exists.
# ./birds_augmented/train//ARARIPE MANAKIN/ already exists.
# ./birds_augmented/train//ASHY THRUSHBIRD/ already exists.
# ./birds_augmented/train//ASIAN CRESTED IBIS/ already exists.
# ./birds_augmented/train//AZURE JAY/ already exists.
# ./birds_augmented/train//AZURE TANAGER/ already exists.
# ./birds_augmented/train//AZURE TIT/ already exists.
# ./birds_augmented/train//BAIKAL TEAL/ already exists.
# ./birds_augmented/train//BALD EAGLE/ already exists.
# ./birds_augmented/train//BALD IBIS/ already exists.
# ./birds_augmented/train//BALI STARLING/ already exists.
# ./birds_augmented/train//BALTIMORE ORIOLE/ already exists.
# ./birds_augmented/train//BANANAQUIT/ already exists.
# ./birds_augmented/train//BAND TAILED GUAN/ already exists.
# ./birds_augmented/train//BANDED BROADBILL/ already exists.
# ./birds_augmented/train//BANDED PITA/ already exists.
# ./birds_augmented/train//BANDED STILT/ already exists.
# ./birds_augmented/train//BAR-TAILED GODWIT/ already exists.
# ./birds_augmented/train//BARN OWL/ already exists.
# ./birds_augmented/train//BARN SWALLOW/ already exists.
# ./birds_augmented/train//BARRED PUFFBIRD/ already exists.
# ./birds_augmented/train//BARROWS GOLDENEYE/ already exists.
# ./birds_augmented/train//BAY-BREASTED WARBLER/ already exists.
# ./birds_augmented/train//BEARDED BARBET/ already exists.
# ./birds_augmented/train//BEARDED BELLBIRD/ already exists.
# ./birds_augmented/train//BEARDED REEDLING/ already exists.
# ./birds_augmented/train//BELTED KINGFISHER/ already exists.
# ./birds_augmented/train//BIRD OF PARADISE/ already exists.
# ./birds_augmented/train//BLACK & YELLOW BROADBILL/ already exists.
# ./birds_augmented/train//BLACK BAZA/ already exists.
# ./birds_augmented/train//BLACK COCKATO/ already exists.
# ./birds_augmented/train//BLACK FRANCOLIN/ already exists.
# ./birds_augmented/train//BLACK SKIMMER/ already exists.
# ./birds_augmented/train//BLACK SWAN/ already exists.
# ./birds_augmented/train//BLACK TAIL CRAKE/ already exists.
# ./birds_augmented/train//BLACK THROATED BUSHTIT/ already exists.
# ./birds_augmented/train//BLACK THROATED WARBLER/ already exists.
# ./birds_augmented/train//BLACK VULTURE/ already exists.
# ./birds_augmented/train//BLACK-CAPPED CHICKADEE/ already exists.
# ./birds_augmented/train//BLACK-NECKED GREBE/ already exists.
# ./birds_augmented/train//BLACK-THROATED SPARROW/ already exists.
# ./birds_augmented/train//BLACKBURNIAM WARBLER/ already exists.
# ./birds_augmented/train//BLONDE CRESTED WOODPECKER/ already exists.
# ./birds_augmented/train//BLUE COAU/ already exists.
# ./birds_augmented/train//BLUE GROUSE/ already exists.
# ./birds_augmented/train//BLUE HERON/ already exists.
# ./birds_augmented/train//BLUE THROATED TOUCANET/ already exists.
# ./birds_augmented/train//BOBOLINK/ already exists.
# ./birds_augmented/train//BORNEAN BRISTLEHEAD/ already exists.
# ./birds_augmented/train//BORNEAN LEAFBIRD/ already exists.
# ./birds_augmented/train//BORNEAN PHEASANT/ already exists.
# ./birds_augmented/train//BRANDT CORMARANT/ already exists.
# ./birds_augmented/train//BROWN CREPPER/ already exists.
# ./birds_augmented/train//BROWN NOODY/ already exists.
# ./birds_augmented/train//BROWN THRASHER/ already exists.
# ./birds_augmented/train//BULWERS PHEASANT/ already exists.
# ./birds_augmented/train//BUSH TURKEY/ already exists.
# ./birds_augmented/train//CACTUS WREN/ already exists.
# ./birds_augmented/train//CALIFORNIA CONDOR/ already exists.
# ./birds_augmented/train//CALIFORNIA GULL/ already exists.
# ./birds_augmented/train//CALIFORNIA QUAIL/ already exists.
# ./birds_augmented/train//CANARY/ already exists.
# ./birds_augmented/train//CAPE GLOSSY STARLING/ already exists.
# ./birds_augmented/train//CAPE LONGCLAW/ already exists.
# ./birds_augmented/train//CAPE MAY WARBLER/ already exists.
# ./birds_augmented/train//CAPE ROCK THRUSH/ already exists.
# ./birds_augmented/train//CAPPED HERON/ already exists.
# ./birds_augmented/train//CAPUCHINBIRD/ already exists.
# ./birds_augmented/train//CARMINE BEE-EATER/ already exists.
# ./birds_augmented/train//CASPIAN TERN/ already exists.
# ./birds_augmented/train//CASSOWARY/ already exists.
# ./birds_augmented/train//CEDAR WAXWING/ already exists.
# ./birds_augmented/train//CERULEAN WARBLER/ already exists.
# ./birds_augmented/train//CHARA DE COLLAR/ already exists.
# ./birds_augmented/train//CHATTERING LORY/ already exists.
# ./birds_augmented/train//CHESTNET BELLIED EUPHONIA/ already exists.
# ./birds_augmented/train//CHINESE BAMBOO PARTRIDGE/ already exists.
# ./birds_augmented/train//CHINESE POND HERON/ already exists.
# ./birds_augmented/train//CHIPPING SPARROW/ already exists.
# ./birds_augmented/train//CHUCAO TAPACULO/ already exists.
# ./birds_augmented/train//CHUKAR PARTRIDGE/ already exists.
# ./birds_augmented/train//CINNAMON ATTILA/ already exists.
# ./birds_augmented/train//CINNAMON FLYCATCHER/ already exists.
# ./birds_augmented/train//CINNAMON TEAL/ already exists.
# ./birds_augmented/train//CLARKS NUTCRACKER/ already exists.
# ./birds_augmented/train//COCK OF THE  ROCK/ already exists.
# ./birds_augmented/train//COCKATOO/ already exists.
# ./birds_augmented/train//COLLARED ARACARI/ already exists.
# ./birds_augmented/train//COMMON FIRECREST/ already exists.
# ./birds_augmented/train//COMMON GRACKLE/ already exists.
# ./birds_augmented/train//COMMON HOUSE MARTIN/ already exists.
# ./birds_augmented/train//COMMON IORA/ already exists.
# ./birds_augmented/train//COMMON LOON/ already exists.
# ./birds_augmented/train//COMMON POORWILL/ already exists.
# ./birds_augmented/train//COMMON STARLING/ already exists.
# ./birds_augmented/train//COPPERY TAILED COUCAL/ already exists.
# ./birds_augmented/train//CRAB PLOVER/ already exists.
# ./birds_augmented/train//CRANE HAWK/ already exists.
# ./birds_augmented/train//CREAM COLORED WOODPECKER/ already exists.
# ./birds_augmented/train//CRESTED AUKLET/ already exists.
# ./birds_augmented/train//CRESTED CARACARA/ already exists.
# ./birds_augmented/train//CRESTED COUA/ already exists.
# ./birds_augmented/train//CRESTED FIREBACK/ already exists.
# ./birds_augmented/train//CRESTED KINGFISHER/ already exists.
# ./birds_augmented/train//CRESTED NUTHATCH/ already exists.
# ./birds_augmented/train//CRESTED OROPENDOLA/ already exists.
# ./birds_augmented/train//CRESTED SHRIKETIT/ already exists.
# ./birds_augmented/train//CRIMSON CHAT/ already exists.
# ./birds_augmented/train//CRIMSON SUNBIRD/ already exists.
# ./birds_augmented/train//CROW/ already exists.
# ./birds_augmented/train//CROWNED PIGEON/ already exists.
# ./birds_augmented/train//CUBAN TODY/ already exists.
# ./birds_augmented/train//CUBAN TROGON/ already exists.
# ./birds_augmented/train//CURL CRESTED ARACURI/ already exists.
# ./birds_augmented/train//D-ARNAUDS BARBET/ already exists.
# ./birds_augmented/train//DARK EYED JUNCO/ already exists.
# ./birds_augmented/train//DEMOISELLE CRANE/ already exists.
# ./birds_augmented/train//DOUBLE BARRED FINCH/ already exists.
# ./birds_augmented/train//DOUBLE BRESTED CORMARANT/ already exists.
# ./birds_augmented/train//DOUBLE EYED FIG PARROT/ already exists.
# ./birds_augmented/train//DOWNY WOODPECKER/ already exists.
# ./birds_augmented/train//EARED PITA/ already exists.
# ./birds_augmented/train//EASTERN BLUEBIRD/ already exists.
# ./birds_augmented/train//EASTERN GOLDEN WEAVER/ already exists.
# ./birds_augmented/train//EASTERN MEADOWLARK/ already exists.
# ./birds_augmented/train//EASTERN ROSELLA/ already exists.
# ./birds_augmented/train//EASTERN TOWEE/ already exists.
# ./birds_augmented/train//ELEGANT TROGON/ already exists.
# ./birds_augmented/train//ELLIOTS  PHEASANT/ already exists.
# ./birds_augmented/train//EMPEROR PENGUIN/ already exists.
# ./birds_augmented/train//EMU/ already exists.
# ./birds_augmented/train//ENGGANO MYNA/ already exists.
# ./birds_augmented/train//EURASIAN GOLDEN ORIOLE/ already exists.
# ./birds_augmented/train//EURASIAN MAGPIE/ already exists.
# ./birds_augmented/train//EVENING GROSBEAK/ already exists.
# ./birds_augmented/train//FAIRY BLUEBIRD/ already exists.
# ./birds_augmented/train//FIRE TAILLED MYZORNIS/ already exists.
# ./birds_augmented/train//FLAME TANAGER/ already exists.
# ./birds_augmented/train//FLAMINGO/ already exists.
# ./birds_augmented/train//FRIGATE/ already exists.
# ./birds_augmented/train//GAMBELS QUAIL/ already exists.
# ./birds_augmented/train//GANG GANG COCKATOO/ already exists.
# ./birds_augmented/train//GILA WOODPECKER/ already exists.
# ./birds_augmented/train//GILDED FLICKER/ already exists.
# ./birds_augmented/train//GLOSSY IBIS/ already exists.
# ./birds_augmented/train//GO AWAY BIRD/ already exists.
# ./birds_augmented/train//GOLD WING WARBLER/ already exists.
# ./birds_augmented/train//GOLDEN CHEEKED WARBLER/ already exists.
# ./birds_augmented/train//GOLDEN CHLOROPHONIA/ already exists.
# ./birds_augmented/train//GOLDEN EAGLE/ already exists.
# ./birds_augmented/train//GOLDEN PHEASANT/ already exists.
# ./birds_augmented/train//GOLDEN PIPIT/ already exists.
# ./birds_augmented/train//GOULDIAN FINCH/ already exists.
# ./birds_augmented/train//GRAY CATBIRD/ already exists.
# ./birds_augmented/train//GRAY KINGBIRD/ already exists.
# ./birds_augmented/train//GRAY PARTRIDGE/ already exists.
# ./birds_augmented/train//GREAT GRAY OWL/ already exists.
# ./birds_augmented/train//GREAT KISKADEE/ already exists.
# ./birds_augmented/train//GREAT POTOO/ already exists.
# ./birds_augmented/train//GREATOR SAGE GROUSE/ already exists.
# ./birds_augmented/train//GREEN BROADBILL/ already exists.
# ./birds_augmented/train//GREEN JAY/ already exists.
# ./birds_augmented/train//GREEN MAGPIE/ already exists.
# ./birds_augmented/train//GREY PLOVER/ already exists.
# ./birds_augmented/train//GROVED BILLED ANI/ already exists.
# ./birds_augmented/train//GUINEA TURACO/ already exists.
# ./birds_augmented/train//GUINEAFOWL/ already exists.
# ./birds_augmented/train//GYRFALCON/ already exists.
# ./birds_augmented/train//HARLEQUIN DUCK/ already exists.
# ./birds_augmented/train//HARPY EAGLE/ already exists.
# ./birds_augmented/train//HAWAIIAN GOOSE/ already exists.
# ./birds_augmented/train//HELMET VANGA/ already exists.
# ./birds_augmented/train//HIMALAYAN MONAL/ already exists.
# ./birds_augmented/train//HOATZIN/ already exists.
# ./birds_augmented/train//HOODED MERGANSER/ already exists.
# ./birds_augmented/train//HOOPOES/ already exists.
# ./birds_augmented/train//HORNBILL/ already exists.
# ./birds_augmented/train//HORNED GUAN/ already exists.
# ./birds_augmented/train//HORNED LARK/ already exists.
# ./birds_augmented/train//HORNED SUNGEM/ already exists.
# ./birds_augmented/train//HOUSE FINCH/ already exists.
# ./birds_augmented/train//HOUSE SPARROW/ already exists.
# ./birds_augmented/train//HYACINTH MACAW/ already exists.
# ./birds_augmented/train//IMPERIAL SHAQ/ already exists.
# ./birds_augmented/train//INCA TERN/ already exists.
# ./birds_augmented/train//INDIAN BUSTARD/ already exists.
# ./birds_augmented/train//INDIAN PITTA/ already exists.
# ./birds_augmented/train//INDIAN ROLLER/ already exists.
# ./birds_augmented/train//INDIGO BUNTING/ already exists.
# ./birds_augmented/train//IWI/ already exists.
# ./birds_augmented/train//JABIRU/ already exists.
# ./birds_augmented/train//JAVA SPARROW/ already exists.
# ./birds_augmented/train//KAGU/ already exists.
# ./birds_augmented/train//KAKAPO/ already exists.
# ./birds_augmented/train//KILLDEAR/ already exists.
# ./birds_augmented/train//KING VULTURE/ already exists.
# ./birds_augmented/train//KIWI/ already exists.
# ./birds_augmented/train//KOOKABURRA/ already exists.
# ./birds_augmented/train//LARK BUNTING/ already exists.
# ./birds_augmented/train//LAZULI BUNTING/ already exists.
# ./birds_augmented/train//LILAC ROLLER/ already exists.
# ./birds_augmented/train//LONG-EARED OWL/ already exists.
# ./birds_augmented/train//MAGPIE GOOSE/ already exists.
# ./birds_augmented/train//MALABAR HORNBILL/ already exists.
# ./birds_augmented/train//MALACHITE KINGFISHER/ already exists.
# ./birds_augmented/train//MALAGASY WHITE EYE/ already exists.
# ./birds_augmented/train//MALEO/ already exists.
# ./birds_augmented/train//MALLARD DUCK/ already exists.
# ./birds_augmented/train//MANDRIN DUCK/ already exists.
# ./birds_augmented/train//MANGROVE CUCKOO/ already exists.
# ./birds_augmented/train//MARABOU STORK/ already exists.
# ./birds_augmented/train//MASKED BOOBY/ already exists.
# ./birds_augmented/train//MASKED LAPWING/ already exists.
# ./birds_augmented/train//MIKADO  PHEASANT/ already exists.
# ./birds_augmented/train//MOURNING DOVE/ already exists.
# ./birds_augmented/train//MYNA/ already exists.
# ./birds_augmented/train//NICOBAR PIGEON/ already exists.
# ./birds_augmented/train//NOISY FRIARBIRD/ already exists.
# ./birds_augmented/train//NORTHERN CARDINAL/ already exists.
# ./birds_augmented/train//NORTHERN FLICKER/ already exists.
# ./birds_augmented/train//NORTHERN FULMAR/ already exists.
# ./birds_augmented/train//NORTHERN GANNET/ already exists.
# ./birds_augmented/train//NORTHERN GOSHAWK/ already exists.
# ./birds_augmented/train//NORTHERN JACANA/ already exists.
# ./birds_augmented/train//NORTHERN MOCKINGBIRD/ already exists.
# ./birds_augmented/train//NORTHERN PARULA/ already exists.
# ./birds_augmented/train//NORTHERN RED BISHOP/ already exists.
# ./birds_augmented/train//NORTHERN SHOVELER/ already exists.
# ./birds_augmented/train//OCELLATED TURKEY/ already exists.
# ./birds_augmented/train//OKINAWA RAIL/ already exists.
# ./birds_augmented/train//ORANGE BRESTED BUNTING/ already exists.
# ./birds_augmented/train//ORIENTAL BAY OWL/ already exists.
# ./birds_augmented/train//OSPREY/ already exists.
# ./birds_augmented/train//OSTRICH/ already exists.
# ./birds_augmented/train//OVENBIRD/ already exists.
# ./birds_augmented/train//OYSTER CATCHER/ already exists.
# ./birds_augmented/train//PAINTED BUNTING/ already exists.
# ./birds_augmented/train//PALILA/ already exists.
# ./birds_augmented/train//PARADISE TANAGER/ already exists.
# ./birds_augmented/train//PARAKETT  AKULET/ already exists.
# ./birds_augmented/train//PARUS MAJOR/ already exists.
# ./birds_augmented/train//PATAGONIAN SIERRA FINCH/ already exists.
# ./birds_augmented/train//PEACOCK/ already exists.
# ./birds_augmented/train//PELICAN/ already exists.
# ./birds_augmented/train//PEREGRINE FALCON/ already exists.
# ./birds_augmented/train//PHILIPPINE EAGLE/ already exists.
# ./birds_augmented/train//PINK ROBIN/ already exists.
# ./birds_augmented/train//POMARINE JAEGER/ already exists.
# ./birds_augmented/train//PUFFIN/ already exists.
# ./birds_augmented/train//PURPLE FINCH/ already exists.
# ./birds_augmented/train//PURPLE GALLINULE/ already exists.
# ./birds_augmented/train//PURPLE MARTIN/ already exists.
# ./birds_augmented/train//PURPLE SWAMPHEN/ already exists.
# ./birds_augmented/train//PYGMY KINGFISHER/ already exists.
# ./birds_augmented/train//QUETZAL/ already exists.
# ./birds_augmented/train//RAINBOW LORIKEET/ already exists.
# ./birds_augmented/train//RAZORBILL/ already exists.
# ./birds_augmented/train//RED BEARDED BEE EATER/ already exists.
# ./birds_augmented/train//RED BELLIED PITTA/ already exists.
# ./birds_augmented/train//RED BROWED FINCH/ already exists.
# ./birds_augmented/train//RED FACED CORMORANT/ already exists.
# ./birds_augmented/train//RED FACED WARBLER/ already exists.
# ./birds_augmented/train//RED FODY/ already exists.
# ./birds_augmented/train//RED HEADED DUCK/ already exists.
# ./birds_augmented/train//RED HEADED WOODPECKER/ already exists.
# ./birds_augmented/train//RED HONEY CREEPER/ already exists.
# ./birds_augmented/train//RED NAPED TROGON/ already exists.
# ./birds_augmented/train//RED TAILED HAWK/ already exists.
# ./birds_augmented/train//RED TAILED THRUSH/ already exists.
# ./birds_augmented/train//RED WINGED BLACKBIRD/ already exists.
# ./birds_augmented/train//RED WISKERED BULBUL/ already exists.
# ./birds_augmented/train//REGENT BOWERBIRD/ already exists.
# ./birds_augmented/train//RING-NECKED PHEASANT/ already exists.
# ./birds_augmented/train//ROADRUNNER/ already exists.
# ./birds_augmented/train//ROBIN/ already exists.
# ./birds_augmented/train//ROCK DOVE/ already exists.
# ./birds_augmented/train//ROSY FACED LOVEBIRD/ already exists.
# ./birds_augmented/train//ROUGH LEG BUZZARD/ already exists.
# ./birds_augmented/train//ROYAL FLYCATCHER/ already exists.
# ./birds_augmented/train//RUBY THROATED HUMMINGBIRD/ already exists.
# ./birds_augmented/train//RUDY KINGFISHER/ already exists.
# ./birds_augmented/train//RUFOUS KINGFISHER/ already exists.
# ./birds_augmented/train//RUFUOS MOTMOT/ already exists.
# ./birds_augmented/train//SAMATRAN THRUSH/ already exists.
# ./birds_augmented/train//SAND MARTIN/ already exists.
# ./birds_augmented/train//SANDHILL CRANE/ already exists.
# ./birds_augmented/train//SATYR TRAGOPAN/ already exists.
# ./birds_augmented/train//SCARLET CROWNED FRUIT DOVE/ already exists.
# ./birds_augmented/train//SCARLET IBIS/ already exists.
# ./birds_augmented/train//SCARLET MACAW/ already exists.
# ./birds_augmented/train//SCARLET TANAGER/ already exists.
# ./birds_augmented/train//SHOEBILL/ already exists.
# ./birds_augmented/train//SHORT BILLED DOWITCHER/ already exists.
# ./birds_augmented/train//SMITHS LONGSPUR/ already exists.
# ./birds_augmented/train//SNOWY EGRET/ already exists.
# ./birds_augmented/train//SNOWY OWL/ already exists.
# ./birds_augmented/train//SORA/ already exists.
# ./birds_augmented/train//SPANGLED COTINGA/ already exists.
# ./birds_augmented/train//SPLENDID WREN/ already exists.
# ./birds_augmented/train//SPOON BILED SANDPIPER/ already exists.
# ./birds_augmented/train//SPOONBILL/ already exists.
# ./birds_augmented/train//SPOTTED CATBIRD/ already exists.
# ./birds_augmented/train//SRI LANKA BLUE MAGPIE/ already exists.
# ./birds_augmented/train//STEAMER DUCK/ already exists.
# ./birds_augmented/train//STORK BILLED KINGFISHER/ already exists.
# ./birds_augmented/train//STRAWBERRY FINCH/ already exists.
# ./birds_augmented/train//STRIPED OWL/ already exists.
# ./birds_augmented/train//STRIPPED MANAKIN/ already exists.
# ./birds_augmented/train//STRIPPED SWALLOW/ already exists.
# ./birds_augmented/train//SUPERB STARLING/ already exists.
# ./birds_augmented/train//SWINHOES PHEASANT/ already exists.
# ./birds_augmented/train//TAILORBIRD/ already exists.
# ./birds_augmented/train//TAIWAN MAGPIE/ already exists.
# ./birds_augmented/train//TAKAHE/ already exists.
# ./birds_augmented/train//TASMANIAN HEN/ already exists.
# ./birds_augmented/train//TEAL DUCK/ already exists.
# ./birds_augmented/train//TIT MOUSE/ already exists.
# ./birds_augmented/train//TOUCHAN/ already exists.
# ./birds_augmented/train//TOWNSENDS WARBLER/ already exists.
# ./birds_augmented/train//TREE SWALLOW/ already exists.
# ./birds_augmented/train//TROPICAL KINGBIRD/ already exists.
# ./birds_augmented/train//TRUMPTER SWAN/ already exists.
# ./birds_augmented/train//TURKEY VULTURE/ already exists.
# ./birds_augmented/train//TURQUOISE MOTMOT/ already exists.
# ./birds_augmented/train//UMBRELLA BIRD/ already exists.
# ./birds_augmented/train//VARIED THRUSH/ already exists.
# ./birds_augmented/train//VENEZUELIAN TROUPIAL/ already exists.
# ./birds_augmented/train//VERMILION FLYCATHER/ already exists.
# ./birds_augmented/train//VICTORIA CROWNED PIGEON/ already exists.
# ./birds_augmented/train//VIOLET GREEN SWALLOW/ already exists.
# ./birds_augmented/train//VULTURINE GUINEAFOWL/ already exists.
# ./birds_augmented/train//WALL CREAPER/ already exists.
# ./birds_augmented/train//WATTLED CURASSOW/ already exists.
# ./birds_augmented/train//WATTLED LAPWING/ already exists.
# ./birds_augmented/train//WHIMBREL/ already exists.
# ./birds_augmented/train//WHITE BROWED CRAKE/ already exists.
# ./birds_augmented/train//WHITE CHEEKED TURACO/ already exists.
# ./birds_augmented/train//WHITE NECKED RAVEN/ already exists.
# ./birds_augmented/train//WHITE TAILED TROPIC/ already exists.
# ./birds_augmented/train//WHITE THROATED BEE EATER/ already exists.
# ./birds_augmented/train//WILD TURKEY/ already exists.
# ./birds_augmented/train//WILSONS BIRD OF PARADISE/ already exists.
# ./birds_augmented/train//WOOD DUCK/ already exists.
# ./birds_augmented/train//YELLOW BELLIED FLOWERPECKER/ already exists.
# ./birds_augmented/train//YELLOW CACIQUE/ already exists.
# ./birds_augmented/train//YELLOW HEADED BLACKBIRD/ already exists.

# %% [markdown]
# ### Ensure all augnented filders now only have 120 images

# %%
for k, char in map_birds.items():
    augmented_size = len(os.listdir(aug_path + '/train' + '/%s/' % char))
    print(augmented_size)
# Out:
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120

# %% [markdown]
# ### Function to get the images into numpy array format for analysis

# %%
def load_pictures(BGR):

    train_pics = []
    train_labels = []
    
    test_pics = []
    test_labels = []
    
    valid_pics = []
    valid_labels = []
    
    for k, char in map_birds.items():
        pictures_train = [k for k in glob.glob(aug_path + '/train/%s/*' % char)]

        for pic in pictures_train:
            a = cv2.imread(pic)
            if BGR:
                a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
            a = cv2.resize(a, (pic_size,pic_size))
            train_pics.append(a)
            train_labels.append(k)
            
        pictures_test = [k for k in glob.glob(image_dir + '/test/%s/*' % char)]
        
        for pic in pictures_test:
            a = cv2.imread(pic)
            if BGR:
                a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
            a = cv2.resize(a, (pic_size,pic_size))
            test_pics.append(a)
            test_labels.append(k)
            
        pictures_valid = [k for k in glob.glob(image_dir + '/valid/%s/*' % char)]
        
        for pic in pictures_valid:
            a = cv2.imread(pic)
            if BGR:
                a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
            a = cv2.resize(a, (pic_size,pic_size))
            valid_pics.append(a)
            valid_labels.append(k)

    return np.array(train_pics), np.array(train_labels), np.array(test_pics), np.array(test_labels), np.array(valid_pics), np.array(valid_labels)

# %% [markdown]
# ### Function to load or save dataset in a useful way for analysis

# %%
def get_dataset(save=False, load=False, BGR=False):
    """
    Ensure image content is float32 and images are normalized (/255.). 
    The dataset could be saved or loaded from h5 files.
    :param save: saving or not the created dataset
    :param load: loading or not the dataset
    :param BGR: boolean to use true color for the picture (RGB instead of BGR for plt)
    :return: X_train, X_test, y_train, y_test (numpy arrays)
    """
    if load:
        h5f = h5py.File('dataset.h5','r')
        X_train = h5f['X_train'][:]
        X_val = h5f['X_val'][:]
        X_test = h5f['X_test'][:]
        h5f.close()    

        h5f = h5py.File('labels.h5','r')
        y_train = h5f['y_train'][:]
        y_val = h5f['y_val'][:]
        y_test = h5f['y_test'][:]
        h5f.close()    
    else:
        X_train, y_train, X_test, y_test, X_val, y_val = load_pictures(BGR)
        y_train = keras.utils.to_categorical(y_train, num_classes)
        y_test = keras.utils.to_categorical(y_test, num_classes)
        y_val = keras.utils.to_categorical(y_val, num_classes)
        
        if save:
            h5f = h5py.File('dataset.h5', 'w')
            h5f.create_dataset('X_train', data=X_train)
            h5f.create_dataset('X_val', data=X_val)
            h5f.create_dataset('X_test', data=X_test)
            h5f.close()

            h5f = h5py.File('labels.h5', 'w')
            h5f.create_dataset('y_train', data=y_train)
            h5f.create_dataset('y_val', data=y_val)
            h5f.create_dataset('y_test', data=y_test)
            h5f.close()
            
    X_train = X_train.astype('float32') / 255.
    X_val = X_val.astype('float32') / 255.
    X_test = X_test.astype('float32') / 255.
    print("Train", X_train.shape, y_train.shape)
    print("Val", X_val.shape, y_val.shape)
    print("Test", X_test.shape, y_test.shape)
    if not load:
        dist = {k:tuple(d[k] for d in [dict(Counter(np.where(y_train==1)[1])), dict(Counter(np.where(y_test==1)[1]))])
                for k in range(num_classes)}
        print('\n'.join(["%s : %d train pictures & %d val pictures" % (map_birds[k], v[0], v[1]) 
            for k,v in sorted(dist.items(), key=lambda x:x[1][0], reverse=True)]))
    return X_train, X_val, X_test, y_train, y_val, y_test

# %% [markdown]
# ### Create a learning rate function for the models below

# %%
def lr_schedule(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

# %% [markdown]
# ### Build the first the CNN model

# %%
def create_model_six_conv(input_shape):
    """
    CNN Keras model with 6 convolutions.
    :param input_shape: input shape, generally X_train.shape[1:]
    :return: Keras model, RMS prop optimizer
    """
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.1))
    
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.1))

    model.add(Conv2D(256, (3, 3), padding='same')) 
    model.add(Activation('relu'))
    model.add(Conv2D(256, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    model.add(Dense(num_classes, activation='softmax'))
    opt = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(loss='categorical_crossentropy',
          optimizer=opt,
          metrics=['accuracy'])  
    return model, opt

# %% [markdown]
# ### Function to run the CNN models

# %%
def training(model, X_train, X_val, y_train, y_val, best_weights_path, data_augmentation=True):

    if data_augmentation:
        datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
            width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
            height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
            horizontal_flip=False,  # randomly flip images
            vertical_flip=True)  # randomly flip images
        # Compute quantities required for feature-wise normalization
        # (std, mean, and principal components if ZCA whitening is applied).
        datagen.fit(X_train)
        filepath = best_weights_path
        checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
        callbacks_list = [LearningRateScheduler(lr_schedule) ,checkpoint]
        history = model.fit(datagen.flow(X_train, y_train,
                            batch_size=batch_size),
                            steps_per_epoch=X_train.shape[0] // batch_size,
                            epochs=epochs,
                            validation_data=(X_val, y_val),
                            callbacks=callbacks_list)        
    else:
        history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(X_val, y_val),
          shuffle=True)
    return model, history

# %% [markdown]
# ### Run the first model

# %%
if __name__ == '__main__':
    X_train, X_val, X_test, y_train, y_val, y_test = get_dataset(load=True)
    model, opt = create_model_six_conv(X_train.shape[1:])
    model, history = training(model, X_train, X_val, y_train, y_val, best_weights_path = best_weights_path_cnn, data_augmentation=True)
# Out:
# Train (45000, 224, 224, 3) (45000, 375)
# Val (1875, 224, 224, 3) (1875, 375)
# Test (1875, 224, 224, 3) (1875, 375)
# Epoch 1/30
#    2/1406 [..............................] - ETA: 1:23 - loss: 5.9262 - accuracy: 0.0000e+00WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.
# 1406/1406 [==============================] - 343s 244ms/step - loss: 0.8817 - accuracy: 0.7633 - val_loss: 0.8865 - val_accuracy: 0.7675
# Epoch 20/30
# 1406/1406 [==============================] - 340s 242ms/step - loss: 0.8083 - accuracy: 0.7795 - val_loss: 0.8888 - val_accuracy: 0.7765
# Epoch 21/30
# 1406/1406 [==============================] - 323s 230ms/step - loss: 0.7437 - accuracy: 0.7953 - val_loss: 0.8803 - val_accuracy: 0.7781
# Epoch 22/30
# 1406/1406 [==============================] - 324s 230ms/step - loss: 0.7033 - accuracy: 0.8069 - val_loss: 0.8705 - val_accuracy: 0.7845
# Epoch 23/30
# 1406/1406 [==============================] - 327s 232ms/step - loss: 0.6476 - accuracy: 0.8185 - val_loss: 0.8526 - val_accuracy: 0.7883
# Epoch 24/30
# 1406/1406 [==============================] - 332s 236ms/step - loss: 0.5933 - accuracy: 0.8339 - val_loss: 0.8742 - val_accuracy: 0.7947
# Epoch 25/30
# 1406/1406 [==============================] - 320s 228ms/step - loss: 0.5625 - accuracy: 0.8424 - val_loss: 0.8404 - val_accuracy: 0.8064
# Epoch 26/30
# 1406/1406 [==============================] - 315s 224ms/step - loss: 0.5327 - accuracy: 0.8487 - val_loss: 0.8426 - val_accuracy: 0.8091
# Epoch 27/30
# 1406/1406 [==============================] - 314s 224ms/step - loss: 0.4962 - accuracy: 0.8593 - val_loss: 0.8581 - val_accuracy: 0.8053
# Epoch 28/30
# 1406/1406 [==============================] - 312s 222ms/step - loss: 0.4720 - accuracy: 0.8658 - val_loss: 0.8484 - val_accuracy: 0.8037
# Epoch 29/30
# 1406/1406 [==============================] - 313s 222ms/step - loss: 0.4336 - accuracy: 0.8752 - val_loss: 0.9156 - val_accuracy: 0.8032
# Epoch 30/30
# 1406/1406 [==============================] - 318s 226ms/step - loss: 0.4147 - accuracy: 0.8798 - val_loss: 0.8869 - val_accuracy: 0.8080

# %% [markdown]
# ### Create Variables for Subsequent Graphs

# %%
acc = history.history['accuracy'] #Create training accuracy
val_acc = history.history['val_accuracy'] #Create validation accuracy
loss = history.history['loss'] #Create training loss
val_loss = history.history['val_loss'] #Create validation loss
epochs_range = range(epochs) #Number of epochs

# %% [markdown]
# ### Plot the Training and Validation Accuracy and Loss

# %%
# accuracy plot
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# loss plot
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
y_pred = model.predict(X_test)
print('\n', classification_report(np.where(y_test > 0)[1],
                                  np.argmax(y_pred, axis=1),
                                  target_names=list(map_birds.values())), sep='')
# Out:
#                              precision    recall  f1-score   support
#
#             ABBOTTS BABBLER       0.67      0.40      0.50         5
#               ABBOTTS BOOBY       0.00      0.00      0.00         5
#  ABYSSINIAN GROUND HORNBILL       0.50      0.20      0.29         5
#       AFRICAN CROWNED CRANE       1.00      1.00      1.00         5
#      AFRICAN EMERALD CUCKOO       1.00      0.80      0.89         5
#           AFRICAN FIREFINCH       0.80      0.80      0.80         5
#      AFRICAN OYSTER CATCHER       1.00      0.80      0.89         5
#                   ALBATROSS       0.75      0.60      0.67         5
#              ALBERTS TOWHEE       0.75      0.60      0.67         5
#           SWINHOES PHEASANT       0.57      0.80      0.67         5
#                  TAILORBIRD       1.00      1.00      1.00         5
#               TAIWAN MAGPIE       1.00      1.00      1.00         5
#                      TAKAHE       1.00      0.80      0.89         5
#               TASMANIAN HEN       1.00      0.60      0.75         5
#                   TEAL DUCK       0.83      1.00      0.91         5
#                   TIT MOUSE       0.50      0.40      0.44         5
#                     TOUCHAN       1.00      1.00      1.00         5
#           TOWNSENDS WARBLER       1.00      0.80      0.89         5
#                TREE SWALLOW       0.45      1.00      0.62         5
#           TROPICAL KINGBIRD       1.00      0.80      0.89         5
#               TRUMPTER SWAN       0.83      1.00      0.91         5
#              TURKEY VULTURE       0.75      0.60      0.67         5
#            TURQUOISE MOTMOT       1.00      1.00      1.00         5
#               UMBRELLA BIRD       0.83      1.00      0.91         5
#               VARIED THRUSH       1.00      1.00      1.00         5
#        VENEZUELIAN TROUPIAL       0.62      1.00      0.77         5
#         VERMILION FLYCATHER       0.83      1.00      0.91         5
#     VICTORIA CROWNED PIGEON       0.83      1.00      0.91         5
#        VIOLET GREEN SWALLOW       0.80      0.80      0.80         5
#        VULTURINE GUINEAFOWL       0.80      0.80      0.80         5
#                WALL CREAPER       1.00      0.80      0.89         5
#            WATTLED CURASSOW       0.50      0.80      0.62         5
#             WATTLED LAPWING       1.00      0.80      0.89         5
#                    WHIMBREL       0.42      1.00      0.59         5
#          WHITE BROWED CRAKE       0.60      0.60      0.60         5
#        WHITE CHEEKED TURACO       1.00      0.80      0.89         5
#          WHITE NECKED RAVEN       0.50      0.20      0.29         5
#         WHITE TAILED TROPIC       1.00      0.40      0.57         5
#    WHITE THROATED BEE EATER       1.00      0.80      0.89         5
#                 WILD TURKEY       0.83      1.00      0.91         5
#    WILSONS BIRD OF PARADISE       1.00      1.00      1.00         5
#                   WOOD DUCK       0.80      0.80      0.80         5
# YELLOW BELLIED FLOWERPECKER       1.00      1.00      1.00         5
#              YELLOW CACIQUE       1.00      0.80      0.89         5
#     YELLOW HEADED BLACKBIRD       0.80      0.80      0.80         5
#
#                    accuracy                           0.83      1875
#                   macro avg       0.85      0.83      0.82      1875
#                weighted avg       0.85      0.83      0.82      1875

# %% [markdown]
# ### Build a Keras Tuner model to see if we can inprove accuracy on our first model

# %%
def build_model(hp):
    # create model object
    model = keras.Sequential([
    
    keras.layers.Conv2D(
        filters=hp.Int('conv_1_filter', min_value=32, max_value=128, step=32), 
        kernel_size=(3, 3),
        activation=hp.Choice('conv_1_activation', values = ['relu', 'elu']),
        padding='same', 
        input_shape=(pic_size,pic_size,3)),  
    keras.layers.Conv2D(
        filters=hp.Int('conv_2_filter', min_value=32, max_value=128, step=32), 
        kernel_size=(3, 3),
        activation=hp.Choice('conv_2_activation', values = ['relu', 'elu'])),
    keras.layers.MaxPooling2D(
        pool_size=(2, 2)),
    keras.layers.Dropout(0.1),
    
    keras.layers.Conv2D(
        filters=hp.Int('conv_3_filter', min_value=32, max_value=128, step=32),
        kernel_size=(3, 3),
        activation=hp.Choice('conv_3_activation', values = ['relu', 'elu']),
        padding='same'),  
    keras.layers.Conv2D(
        filters=hp.Int('conv_4_filter', min_value=32, max_value=128, step=32), 
        kernel_size=(3, 3),
        activation=hp.Choice('conv_4_activation', values = ['relu', 'elu'])),
    keras.layers.MaxPooling2D(
        pool_size=(2, 2)),
    keras.layers.Dropout(0.1),
    
    keras.layers.Conv2D(
        filters=hp.Int('conv_5_filter', min_value=128, max_value=512, step=128),
        kernel_size=(3, 3),
        activation=hp.Choice('conv_5_activation', values = ['relu', 'elu']),
        padding='same'),  
    keras.layers.Conv2D(
        filters=hp.Int('conv_6_filter', min_value=128, max_value=512, step=128),
        kernel_size=(3, 3),
        activation=hp.Choice('conv_6_activation', values = ['relu', 'elu'])),
    keras.layers.MaxPooling2D(
        pool_size=(2, 2)),
    keras.layers.Dropout(0.2),
    
    keras.layers.Flatten(),
    keras.layers.Dense(
        units=hp.Int('dense_1_units', min_value=512, max_value=2048, step=512),
        activation=hp.Choice('dense_1_activation', values = ['relu', 'elu'])),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(num_classes, activation='softmax')
    ])
    
    #compilation of model
    model.compile(
        optimizer=keras.optimizers.SGD(
            lr=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4]), 
            decay=1e-6, 
            momentum=0.9, 
            nesterov=True),
        loss='categorical_crossentropy',
        metrics=['accuracy']) 
    
    return model

# %% [markdown]
# ### Create a random search object and establish an early stopping parameter

# %%
tuner = kt.Hyperband(build_model,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='keras_tuner_results',
                     project_name='bird_tuner')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project keras_tuner_results\bird_tuner\oracle.json

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %% [markdown]
# ### Run the Keras Tuner Model

# %%
X_train, X_val, X_test, y_train, y_val, y_test = get_dataset(load=True)
tuner.search(X_train, y_train, epochs=epochs, validation_data=(X_val, y_val), callbacks=[stop_early])

# %% [markdown]
# ### Get the optimal hyperparameters

# %%
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

# %% [markdown]
# ### Develop a model based off the Keras Tuner results

# %%
def tuned_model_six_conv(input_shape):
    """
    CNN Keras model with 6 convolutions.
    :param input_shape: input shape, generally X_train.shape[1:]
    :return: Keras model, RMS prop optimizer
    """
    model = Sequential()
    model.add(Conv2D(96, (3, 3), padding='same', input_shape=input_shape))
    model.add(Activation('elu'))
    model.add(Conv2D(96, (3, 3)))
    model.add(Activation('elu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.1))
    
    model.add(Conv2D(96, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(384, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.1))

    model.add(Conv2D(384, (3, 3), padding='same')) 
    model.add(Activation('elu'))
    model.add(Conv2D(256, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(1536))
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    model.add(Dense(num_classes, activation='softmax'))
    opt = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(loss='categorical_crossentropy',
          optimizer=opt,
          metrics=['accuracy'])  
    return model, opt

# %% [markdown]
# ### Run the tuned model

# %%
if __name__ == '__main__':
    X_train, X_val, X_test, y_train, y_val, y_test = get_dataset(load=True)
    model, opt = tuned_model_six_conv(X_train.shape[1:])
    model, history = training(model, X_train, X_val, y_train, y_val, best_weights_path = best_weights_path_tuned, data_augmentation=True)
# Out:
# Train (45000, 224, 224, 3) (45000, 375)
# Val (1875, 224, 224, 3) (1875, 375)
# Test (1875, 224, 224, 3) (1875, 375)
# Epoch 1/30
#    2/1406 [..............................] - ETA: 4:49 - loss: 5.9183 - accuracy: 0.0000e+00WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.
30
# 1406/1406 [==============================] - 618s 439ms/step - loss: 0.3674 - accuracy: 0.8945 - val_loss: 0.8914 - val_accuracy: 0.8224
# Epoch 25/30
# 1406/1406 [==============================] - 605s 431ms/step - loss: 0.3369 - accuracy: 0.9026 - val_loss: 0.9132 - val_accuracy: 0.8155
# Epoch 26/30
# 1406/1406 [==============================] - 618s 439ms/step - loss: 0.3040 - accuracy: 0.9117 - val_loss: 0.8609 - val_accuracy: 0.8277
# Epoch 27/30
# 1406/1406 [==============================] - 605s 431ms/step - loss: 0.2791 - accuracy: 0.9185 - val_loss: 0.9694 - val_accuracy: 0.8064
# Epoch 28/30
# 1406/1406 [==============================] - 605s 430ms/step - loss: 0.2555 - accuracy: 0.9254 - val_loss: 0.9223 - val_accuracy: 0.8213
# Epoch 29/30
# 1406/1406 [==============================] - 605s 430ms/step - loss: 0.2461 - accuracy: 0.9277 - val_loss: 0.9190 - val_accuracy: 0.8187
# Epoch 30/30
# 1406/1406 [==============================] - 617s 439ms/step - loss: 0.2279 - accuracy: 0.9314 - val_loss: 0.9193 - val_accuracy: 0.8299

# %% [markdown]
# ### Create variables for use in accuracy plot

# %%
acc = history.history['accuracy'] #Create training accuracy
val_acc = history.history['val_accuracy'] #Create validation accuracy
loss = history.history['loss'] #Create training loss
val_loss = history.history['val_loss'] #Create validation loss
epochs_range = range(epochs) #Number of epochs

# %% [markdown]
# ### Create accuracy and loss charts

# %%
# accuracy plot
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# loss plot
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Create precision, recall, and F1 scores

# %%
y_pred = model.predict(X_test)
print('\n', classification_report(np.argmax(y_test, axis=1),
                                  np.argmax(y_pred, axis=1),
                                  target_names=list(map_birds.values())), sep='')
# Out:
#                              precision    recall  f1-score   support
#
#             ABBOTTS BABBLER       0.67      0.40      0.50         5
#               ABBOTTS BOOBY       0.33      0.20      0.25         5
#  ABYSSINIAN GROUND HORNBILL       1.00      0.60      0.75         5
#       AFRICAN CROWNED CRANE       0.83      1.00      0.91         5
#      AFRICAN EMERALD CUCKOO       1.00      0.60      0.75         5
#           AFRICAN FIREFINCH       0.75      0.60      0.67         5
#      AFRICAN OYSTER CATCHER       1.00      1.00      1.00         5
#                   ALBATROSS       0.75      0.60      0.67         5
#              ALBERTS TOWHEE       1.00      0.80      0.89         5
#        ALEXANDRINE PARAKEET       0.83      1.00      0.91         5
#               ALPINE CHOUGH       0.00      0.00      0.00         5
#       ALTAMIRA YELLOWTHROAT       1.00      0.20      0.33         5
#             AMERICAN AVOCET       0.80      0.80      0.80         5
#            AMERICAN BITTERN       1.00      1.00      1.00         5
#               AMERICAN COOT       1.00      1.00      1.00         5
#          AMERICAN GOLDFINCH       0.83      1.00      0.91         5
#            AMERICAN KESTREL       1.00      1.00      1.00         5
#              AMERICAN PIPIT       1.00      0.80      0.89         5
#           AMERICAN REDSTART       1.00      0.80      0.89         5
#           AMETHYST WOODSTAR       0.71      1.00      0.83         5
#                ANDEAN GOOSE       1.00      0.80      0.89         5
#              ANDEAN LAPWING       0.80      0.80      0.80         5
#               ANDEAN SISKIN       0.50      0.20      0.29         5
#               VARIED THRUSH       1.00      0.80      0.89         5
#        VENEZUELIAN TROUPIAL       0.83      1.00      0.91         5
#         VERMILION FLYCATHER       0.83      1.00      0.91         5
#     VICTORIA CROWNED PIGEON       0.43      0.60      0.50         5
#        VIOLET GREEN SWALLOW       0.83      1.00      0.91         5
#        VULTURINE GUINEAFOWL       0.80      0.80      0.80         5
#                WALL CREAPER       1.00      0.80      0.89         5
#            WATTLED CURASSOW       0.57      0.80      0.67         5
#             WATTLED LAPWING       1.00      0.60      0.75         5
#                    WHIMBREL       1.00      0.60      0.75         5
#          WHITE BROWED CRAKE       0.80      0.80      0.80         5
#        WHITE CHEEKED TURACO       1.00      0.80      0.89         5
#          WHITE NECKED RAVEN       0.67      0.80      0.73         5
#         WHITE TAILED TROPIC       1.00      0.20      0.33         5
#    WHITE THROATED BEE EATER       1.00      0.80      0.89         5
#                 WILD TURKEY       1.00      1.00      1.00         5
#    WILSONS BIRD OF PARADISE       1.00      1.00      1.00         5
#                   WOOD DUCK       1.00      1.00      1.00         5
# YELLOW BELLIED FLOWERPECKER       0.83      1.00      0.91         5
#              YELLOW CACIQUE       1.00      0.60      0.75         5
#     YELLOW HEADED BLACKBIRD       1.00      0.60      0.75         5
#
#                    accuracy                           0.85      1875
#                   macro avg       0.87      0.85      0.84      1875
#                weighted avg       0.87      0.85      0.84      1875
# C:\Users\chris\.conda\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\chris\.conda\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\chris\.conda\envs\gpu\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Create EfficientNet Model

# %%
def create_model_efficientnet(input_shape = pic_size):

    inputs = layers.Input(shape = (input_shape, input_shape, 3))

    outputs = EfficientNetB0(include_top= True, weights = None, classes = num_classes, drop_connect_rate=0.2)(inputs)

    model = Model(inputs, outputs)
    
    model.compile(optimizer = 'adam', 
                  loss = 'categorical_crossentropy', 
                  metrics = ['accuracy']) 
    return model

# %% [markdown]
# ### Function to run the EfficientNet models

# %%
def training(model, X_train, X_val, y_train, y_val, best_weights_path, data_augmentation=True):

    if data_augmentation:
        datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
            width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
            height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
            horizontal_flip=False,  # randomly flip images
            vertical_flip=True)  # randomly flip images
        # Compute quantities required for feature-wise normalization
        # (std, mean, and principal components if ZCA whitening is applied).
        datagen.fit(X_train)
        filepath = best_weights_path
        checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
        callbacks_list = [LearningRateScheduler(lr_schedule) ,checkpoint]
        history = model.fit(datagen.flow(X_train, y_train,
                            batch_size=batch_size),
                            steps_per_epoch=X_train.shape[0] // batch_size,
                            epochs=epochs,
                            validation_data=(X_val, y_val),
                            callbacks=callbacks_list)        
    else:
        history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose = 2,
          validation_data=(X_val, y_val),
          shuffle=True)
    return model, history

# %% [markdown]
# ### Run the EfficientNet Model

# %%
if __name__ == '__main__':
    X_train, X_val, X_test, y_train, y_val, y_test = get_dataset(load=True)
    model = create_model_efficientnet()
    model, history = training(model, X_train, X_val, y_train, y_val, best_weights_path = best_weights_path_EN, data_augmentation=True)
# Out:
# Train (45000, 224, 224, 3) (45000, 375)
# Val (1875, 224, 224, 3) (1875, 375)
# Test (1875, 224, 224, 3) (1875, 375)
# Epoch 1/30
#    2/1406 [..............................] - ETA: 2:19 - loss: 6.0158 - accuracy: 0.0000e+00WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.
# Epoch 20/30
# 1406/1406 [==============================] - 327s 233ms/step - loss: 0.1523 - accuracy: 0.9558 - val_loss: 0.2726 - val_accuracy: 0.9301
# Epoch 21/30
# 1406/1406 [==============================] - 323s 229ms/step - loss: 0.1313 - accuracy: 0.9619 - val_loss: 0.2673 - val_accuracy: 0.9296
# Epoch 22/30
# 1406/1406 [==============================] - 325s 231ms/step - loss: 0.1167 - accuracy: 0.9670 - val_loss: 0.2459 - val_accuracy: 0.9328
# Epoch 23/30
# 1406/1406 [==============================] - 322s 229ms/step - loss: 0.1027 - accuracy: 0.9710 - val_loss: 0.2431 - val_accuracy: 0.9381
# Epoch 24/30
# 1406/1406 [==============================] - 319s 227ms/step - loss: 0.0934 - accuracy: 0.9730 - val_loss: 0.2658 - val_accuracy: 0.9312
# Epoch 25/30
# 1406/1406 [==============================] - 318s 226ms/step - loss: 0.0837 - accuracy: 0.9762 - val_loss: 0.2551 - val_accuracy: 0.9301
# Epoch 26/30
# 1406/1406 [==============================] - 319s 227ms/step - loss: 0.0759 - accuracy: 0.9791 - val_loss: 0.2497 - val_accuracy: 0.9328
# Epoch 27/30
# 1406/1406 [==============================] - 325s 231ms/step - loss: 0.0693 - accuracy: 0.9807 - val_loss: 0.2376 - val_accuracy: 0.9360
# Epoch 28/30
# 1406/1406 [==============================] - 326s 232ms/step - loss: 0.0626 - accuracy: 0.9830 - val_loss: 0.2342 - val_accuracy: 0.9387
# Epoch 29/30
# 1406/1406 [==============================] - 319s 227ms/step - loss: 0.0557 - accuracy: 0.9853 - val_loss: 0.2462 - val_accuracy: 0.9360
# Epoch 30/30
# 1406/1406 [==============================] - 319s 227ms/step - loss: 0.0513 - accuracy: 0.9869 - val_loss: 0.2359 - val_accuracy: 0.9387

# %% [markdown]
# ### Create variables for use in accuracy plot

# %%
acc = history.history['accuracy'] #Create training accuracy
val_acc = history.history['val_accuracy'] #Create validation accuracy
loss = history.history['loss'] #Create training loss
val_loss = history.history['val_loss'] #Create validation loss
epochs_range = range(epochs) #Number of epochs

# %% [markdown]
# ### Create accuracy and loss plots

# %%
# accuracy plot
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# loss plot
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Get precision, recall, and F1 scores

# %%
y_pred = model.predict(X_test)
print('\n', classification_report(np.argmax(y_test, axis=1),
                                  np.argmax(y_pred, axis=1),
                                  target_names=list(map_birds.values())), sep='')
# Out:
#                              precision    recall  f1-score   support
#
#             ABBOTTS BABBLER       1.00      0.80      0.89         5
#               ABBOTTS BOOBY       0.75      0.60      0.67         5
#  ABYSSINIAN GROUND HORNBILL       1.00      1.00      1.00         5
#       AFRICAN CROWNED CRANE       1.00      1.00      1.00         5
#      AFRICAN EMERALD CUCKOO       1.00      0.80      0.89         5
#           AFRICAN FIREFINCH       1.00      1.00      1.00         5
#      AFRICAN OYSTER CATCHER       1.00      1.00      1.00         5
#                   ALBATROSS       0.67      0.80      0.73         5
#              ALBERTS TOWHEE       1.00      1.00      1.00         5
#        ALEXANDRINE PARAKEET       1.00      1.00      1.00         5
#               ALPINE CHOUGH       1.00      0.80      0.89         5
#       ALTAMIRA YELLOWTHROAT       1.00      0.60      0.75         5
#             AMERICAN AVOCET       0.80      0.80      0.80         5
#                   TEAL DUCK       1.00      1.00      1.00         5
#                   TIT MOUSE       1.00      0.60      0.75         5
#                     TOUCHAN       1.00      1.00      1.00         5
#           TOWNSENDS WARBLER       0.83      1.00      0.91         5
#                TREE SWALLOW       1.00      0.80      0.89         5
#           TROPICAL KINGBIRD       1.00      0.80      0.89         5
#               TRUMPTER SWAN       1.00      1.00      1.00         5
#              TURKEY VULTURE       1.00      0.60      0.75         5
#            TURQUOISE MOTMOT       1.00      1.00      1.00         5
#               UMBRELLA BIRD       1.00      1.00      1.00         5
#               VARIED THRUSH       1.00      1.00      1.00         5
#        VENEZUELIAN TROUPIAL       1.00      1.00      1.00         5
#         VERMILION FLYCATHER       1.00      1.00      1.00         5
#     VICTORIA CROWNED PIGEON       0.71      1.00      0.83         5
#        VIOLET GREEN SWALLOW       1.00      1.00      1.00         5
#        VULTURINE GUINEAFOWL       1.00      0.80      0.89         5
#                WALL CREAPER       1.00      1.00      1.00         5
#            WATTLED CURASSOW       0.83      1.00      0.91         5
#             WATTLED LAPWING       1.00      1.00      1.00         5
#                    WHIMBREL       1.00      1.00      1.00         5
#          WHITE BROWED CRAKE       0.80      0.80      0.80         5
#        WHITE CHEEKED TURACO       1.00      0.80      0.89         5
#          WHITE NECKED RAVEN       1.00      1.00      1.00         5
#         WHITE TAILED TROPIC       1.00      1.00      1.00         5
#    WHITE THROATED BEE EATER       1.00      1.00      1.00         5
#                 WILD TURKEY       1.00      1.00      1.00         5
#    WILSONS BIRD OF PARADISE       1.00      1.00      1.00         5
#                   WOOD DUCK       1.00      1.00      1.00         5
# YELLOW BELLIED FLOWERPECKER       1.00      0.80      0.89         5
#              YELLOW CACIQUE       1.00      1.00      1.00         5
#     YELLOW HEADED BLACKBIRD       1.00      1.00      1.00         5
#
#                    accuracy                           0.95      1875
#                   macro avg       0.96      0.95      0.95      1875
#                weighted avg       0.96      0.95      0.95      1875

# %% [markdown]
# ### Save model for use in app

# %%
model.save(best_model_save)

# %% [markdown]
# ### Plot example results of first 16 species

# %%
F = plt.figure(1, (15,20))
grid = ImageGrid(F, 111, nrows_ncols=(4, 4), axes_pad=0, label_mode="1")

for i in range(16):
    char = map_birds[i]
    image = cv2.imread(np.random.choice([k for k in glob.glob(image_dir + '/test/%s/*' % char) if char in k]))
    img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    pic = cv2.resize(image, (pic_size, pic_size)).astype('float32') / 255.
    a = model.predict(pic.reshape(1, pic_size, pic_size, 3))[0]
    actual = char.split('_')[0].title()
    text = sorted(['{:s} : {:.1f}%'.format(map_birds[k].split('_')[0].title(), 100*v) for k,v in enumerate(a)], 
       key=lambda x:float(x.split(':')[1].split('%')[0]), reverse=True)[:3]
    img = cv2.resize(img, (352, 352))
    cv2.rectangle(img, (0,260),(352,352),(255,255,255), -1)
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(img, 'Actual : %s' % actual, (10, 280), font, 0.7,(0,0,0),2,cv2.LINE_AA)
    for k, t in enumerate(text):
        cv2.putText(img, t,(10, 300+k*18), font, 0.65,(0,0,0),2,cv2.LINE_AA)
    grid[i].imshow(img)
